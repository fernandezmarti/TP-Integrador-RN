# %% [markdown]
# A continuación se muestarn las comparaciones a partir de los 10 mejores modelos de la primer etapa (con dropout y sin batch normalization). Debido a que puede haber interferencia entre ellos, seleccionamos los que tienen mejor accuracy

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# ![alt text](image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![alt text](image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
