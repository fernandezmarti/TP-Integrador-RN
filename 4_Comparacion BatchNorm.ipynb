# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import io
from helper import *
# Out:
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.7'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
import mlflow
import mlflow.pytorch
from mlflow.tracking import MlflowClient

# %%
from torch.utils.tensorboard import SummaryWriter
import torchvision.utils as vutils

# %%
mlflow.set_experiment("Clasificador_Imagenes")
# Out:
# <Experiment: artifact_location='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776', creation_time=1749928798555, experiment_id='494564464208363776', last_update_time=1749928798555, lifecycle_stage='active', name='Clasificador_Imagenes', tags={}>

# %%
def log_classification_report(model, loader, writer, device, classes, step, prefix="val"):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    fig_cm, ax = plt.subplots(figsize=(6, 6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
    disp.plot(ax=ax, cmap='Blues', xticks_rotation=45)
    ax.set_title(f'{prefix.title()} - Confusion Matrix')

    # Guardar localmente y subir a MLflow
    fig_path = f"confusion_matrix_{prefix}_epoch_{step}.png"
    fig_cm.savefig(fig_path)
    mlflow.log_artifact(fig_path)
    os.remove(fig_path)

    plot_to_tensorboard(fig_cm, writer, f"{prefix}/confusion_matrix", step)

    cls_report = classification_report(all_labels, all_preds, target_names=classes)
    writer.add_text(f"{prefix}/classification_report", f"<pre>{cls_report}</pre>", step)

    # También loguear texto del reporte
    with open(f"classification_report_{prefix}_epoch_{step}.txt", "w") as f:
        f.write(cls_report)
    mlflow.log_artifact(f.name)
    os.remove(f.name)

# %%
# Entrenamiento y validación
def evaluate(model, loader, writer, device, classes, epoch=None, prefix="val"):
    log_classification_report(model, loader, writer, device, classes, step=epoch , prefix="val")
    model.eval()
    correct, total, loss_sum = 0, 0, 0.0

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for i, (images, labels) in enumerate(loader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)

            loss_sum += loss.item()
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Loguear imágenes del primer batch
            if i == 0 and epoch is not None:
                img_grid = vutils.make_grid(images[:8].cpu(), normalize=True)
                writer.add_image(f"{prefix}/images", img_grid, global_step=epoch)

    acc = 100.0 * correct / total
    avg_loss = loss_sum / len(loader)

    if epoch is not None:
        writer.add_scalar(f"{prefix}/loss", avg_loss, epoch)
        writer.add_scalar(f"{prefix}/accuracy", acc, epoch)

    return avg_loss, acc

# %%
# Paths
train_dir = r'skin-dataset-clasification/data/Split_smol/train/'
val_dir = r'skin-dataset-clasification/data/Split_smol/val/'

# %%
# Crear directorio de logs de tensorboard
log_dir = "runs/experimento_skin"
writer = SummaryWriter(log_dir=log_dir)

# %%
class MLPClassifier(nn.Module):
    def __init__(self, input_size=64*64*3,BatchNorm=False, dropout = 0.0, num_classes=10):
        super().__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_size, 512),
            nn.BatchNorm1d(512),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )
            

    def forward(self, x):
        return self.model(x)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, input_size, dropout = 0.0, num_classes=10):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3,16,3, padding = 1, padding_mode = "reflect"),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(16,32,3, padding = 1, padding_mode = "reflect"),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Flatten(),
            nn.Linear((input_size//4)**2*32, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.model(x)

# %% [markdown]
# **Copiamos los hiperparametros de los mejores 10 modelos y vemos como influye batchnorm**

# %%
# Por nombre
experiment_name = "Clasificador_Imagenes"
experiment = mlflow.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id


client = MlflowClient()

# Opcional: Filtrá por condición, por ejemplo runs exitosos
MLP_models = client.search_runs(
    experiment_ids=[experiment_id],
    filter_string="parameter.model = 'MLPClassifier'", #and attributes.status = 'FINISHED'"
    order_by=["metrics.val_accuracy DESC"],  # o cualquier métrica que uses
    max_results=10
)

# %%
modelnbr=0
for i in range(2):
    for parameters in MLP_models:
        print(f"modelo número: {modelnbr}", end = "\r")
        modelnbr += 1
        hparams= {
            "model": ("MLPClassifier"),
            "input_size":  parameters.data.params['input_size'],
            "batch_size": parameters.data.params['batch_size'],
            "lr": parameters.data.params['lr'],
            "epochs": 200,
            "optimizer": "Adam" if parameters.data.params['optimizer']== "Adam" else "SGD" ,
            "HFlip": parameters.data.params['HFlip'],
            "VFlip": parameters.data.params['VFlip'],
            "RBContrast": parameters.data.params['RBContrast'],
            "loss_fn": "CrossEntropyLoss",
            "train_dir": train_dir,
            "val_dir": val_dir,
            "es_patience": 5,
            "dropout": parameters.data.params['dropout'] if i ==1 else 0,
            "BatchNorm": True
        }
        train_transform = A.Compose([
            A.Resize(int(hparams["input_size"]), int(hparams["input_size"])),
            A.HorizontalFlip(p=hparams["HFlip"]),
            A.VerticalFlip(p=hparams["VFlip"]),
            A.RandomBrightnessContrast(p=hparams["RBContrast"]),
            A.Normalize(),
            ToTensorV2()
        ])
        val_test_transform = A.Compose([
            A.Resize(int(hparams["input_size"]), int(hparams["input_size"])),
            A.Normalize(),
            ToTensorV2()
        ])
        train_dataset = CustomImageDataset(train_dir, transform=train_transform)
        val_dataset   = CustomImageDataset(val_dir, transform=val_test_transform)
        batch_size = int(hparams["batch_size"])
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_dataset, batch_size=batch_size)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        num_classes = len(set(train_dataset.labels))
        model = MLPClassifier(num_classes=num_classes, input_size = int(hparams["input_size"])**2*3, dropout = float(hparams["dropout"])).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=float(hparams["lr"])) if hparams["optimizer"]=="Adam" else optim.SGD(model.parameters(), lr=float(hparams["lr"]))
        hparams["count_params"] = count_parameters(model)
        with mlflow.start_run():
            # Log hiperparámetros
            mlflow.log_params(hparams)
            best_val_acc = 0
            best_val_loss = 0
            best_train_acc = 0
            best_train_loss = 0
            best_epoch = 0
            for epoch in range(hparams["epochs"]):
                model.train()
                running_loss = 0.0
                correct, total = 0, 0
            
                for images, labels in train_loader:
                    images, labels = images.to(device), labels.to(device)
            
                    optimizer.zero_grad()
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizer.step()
            
                    running_loss += loss.item()
                    _, preds = torch.max(outputs, 1)
                    correct += (preds == labels).sum().item()
                    total += labels.size(0)
            
                train_loss = running_loss / len(train_loader)
                train_acc = 100.0 * correct / total
                val_loss, val_acc = evaluate(model, val_loader, writer, device,train_dataset.label_encoder.classes_,epoch=epoch, prefix="val")
            
            
                writer.add_scalar("train/loss", train_loss, epoch)
                writer.add_scalar("train/accuracy", train_acc, epoch)
            
                # Log en MLflow
                mlflow.log_metrics({
                    "train_loss": train_loss,
                    "train_accuracy": train_acc,
                    "val_loss": val_loss,
                    "val_accuracy": val_acc
                }, step=epoch)
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_val_loss = val_loss
                    best_train_acc = train_acc
                    best_train_loss = train_loss
                    best_epoch = epoch
                    # Guardar modelo
                    torch.save(model.state_dict(), "mlp_model.pth")
                    #print("Modelo guardado como 'mlp_model.pth'")
                    mlflow.log_artifact("mlp_model.pth")
                    mlflow.pytorch.log_model(model, artifact_path="pytorch_model")
                elif epoch > best_epoch + int(hparams["es_patience"]):
                    #print("Early Stopping")
                    break
                    
            mlflow.log_metrics({
                    "train_loss": best_train_loss,
                    "train_accuracy": best_train_acc,
                    "val_loss": best_val_loss,
                    "val_accuracy": best_val_acc,
                    "best_epoch": best_epoch
                }, step=epoch+1)
# Out:
# modelo número: 0
# 2025/06/15 23:37:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:38:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 1
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:39:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:39:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 2
# 2025/06/15 23:40:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:40:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:40:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:40:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:40:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:40:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:41:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:41:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:41:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 3
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:41:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:41:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:42:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:42:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:42:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:42:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:42:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:42:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 4
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:43:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:43:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:43:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:43:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:43:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 5
# 2025/06/15 23:43:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:44:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:44:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:44:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:44:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:44:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:44:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 6
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:45:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:45:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:45:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:45:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:45:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 7
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:46:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:46:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:46:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:46:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:46:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:46:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:46:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 8
# 2025/06/15 23:47:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:47:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:47:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:47:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:47:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:47:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:47:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 9
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:48:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:48:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:49:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:49:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:49:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 10
# 2025/06/15 23:50:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:50:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 11
# 2025/06/15 23:51:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:51:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 12
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:52:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:52:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:53:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:53:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 13
# 2025/06/15 23:53:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:53:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:53:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:53:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# modelo número: 15
# 2025/06/15 23:55:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:55:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:55:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:55:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:56:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:56:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:56:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:56:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:56:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:57:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 16
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:57:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:57:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:57:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 17
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:58:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:58:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 18
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/15 23:59:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/15 23:59:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# modelo número: 19
# 2025/06/16 00:00:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:00:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/16 00:00:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:00:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/06/16 00:00:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:00:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:00:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:01:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:01:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:01:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/06/16 00:01:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
print(MLP_models)
# Out:
# [<Run: data=<RunData: metrics={'best_epoch': 25.0,
#  'train_accuracy': 75.57471264367815,
#  'train_loss': 0.6375172741033814,
#  'val_accuracy': 68.88888888888889,
#  'val_loss': 0.9994480684399605}, params={'HFlip': '0.0',
#  'RBContrast': '0.0',
#  'VFlip': '0.5',
#  'batch_size': '16',
#  'count_params': '1640201',
#  'dropout': '0.1',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '32',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.0001',
#  'model': 'MLPClassifier',
#  'optimizer': 'Adam',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:33:47.179796", "model_uuid": '
#                              '"fddbb20deecd4dd28689304cff8e73c3", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:33:53.734788", "model_uuid": '
#                              '"0ad8980c272840f6a7d8f06f0701902c", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:00.152551", "model_uuid": '
#                              '"94e3e824d4ca41a9b293e0966f494a88", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:08.985189", "model_uuid": '
#                              '"86cb68fb989e43e9b56df247b3c9580a", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:15.722240", "model_uuid": '
#                              '"ad6ec2b9f5b64b9b90c3e83dfac6ebcd", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:25.671301", "model_uuid": '
#                              '"0d6bf62b4dbd46178b9fa1c8c1392c9f", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:32.192096", "model_uuid": '
#                              '"a98ebb0c4890427e86b98d82627d05a2", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:45.694597", "model_uuid": '
#                              '"c55904daa0b545a3bcbba7809f1a0460", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:34:54.297844", "model_uuid": '
#                              '"a5ed07f1ad3341e0a7f7070a13ef79f3", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:35:10.510673", "model_uuid": '
#                              '"9058e440a3084a7a8253c9e3ac2a5ba7", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:35:26.557791", "model_uuid": '
#                              '"d22e102da52643f0b78bcefb1d85dca7", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"05925b97182a43f98db25ca5fb2fbe72", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:35:32.295728", "model_uuid": '
#                              '"01683ed594574aa380ca7e0baec0b000", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'colorful-quail-624',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/05925b97182a43f98db25ca5fb2fbe72/artifacts', end_time=1749929750625, experiment_id='494564464208363776', lifecycle_stage='active', run_id='05925b97182a43f98db25ca5fb2fbe72', run_name='colorful-quail-624', run_uuid='05925b97182a43f98db25ca5fb2fbe72', start_time=1749929624514, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'best_epoch': 27.0,
#  'train_accuracy': 68.53448275862068,
#  'train_loss': 0.8321314454078674,
#  'val_accuracy': 65.0,
#  'val_loss': 1.0589604377746582}, params={'HFlip': '0.0',
#  'RBContrast': '0.0',
#  'VFlip': '0.5',
#  'batch_size': '128',
#  'count_params': '6358793',
#  'dropout': '0.2',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '64',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.0001',
#  'model': 'MLPClassifier',
#  'optimizer': 'Adam',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:29:53.760940", "model_uuid": '
#                              '"5d1c45c854784185986c4623cea2d193", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:30:00.329288", "model_uuid": '
#                              '"6238ab64f8cd40fa8e197b978408b491", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:30:06.525593", "model_uuid": '
#                              '"c5ac2dbb96d848729c863ae801e41477", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:30:13.399018", "model_uuid": '
#                              '"46969ac08fb74414a317f57200bb8895", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:45:52.777968", "model_uuid": '
#                              '"62f1f4011d384c9e987f978874b74dfb", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:46:04.494244", "model_uuid": '
#                              '"771981de74f74a2ba202efc441663e8a", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:46:13.080132", "model_uuid": '
#                              '"40c4114dcc3f492aac786744bcaa4886", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:46:18.970969", "model_uuid": '
#                              '"d6b0e328206540d49cb2256c9fff2555", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:46:27.503967", "model_uuid": '
#                              '"3fa6c7a266574b3ea7004172b928b578", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:52:13.692186", "model_uuid": '
#                              '"83aeb8a2d4c34a969b87a98dace508a5", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:52:25.804513", "model_uuid": '
#                              '"f823dec5a5fc4826a23fdc7d84747655", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:52:44.897421", "model_uuid": '
#                              '"23aaf82cfc574fccac10075a9045ff6f", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"b21e76e4edd74d4f8688d0f9a5877f3a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '23:52:56.315231", "model_uuid": '
#                              '"18809bac8b074440839ec505d0103726", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'clumsy-mouse-833',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/b21e76e4edd74d4f8688d0f9a5877f3a/artifacts', end_time=1749945241175, experiment_id='494564464208363776', lifecycle_stage='active', run_id='b21e76e4edd74d4f8688d0f9a5877f3a', run_name='clumsy-mouse-833', run_uuid='b21e76e4edd74d4f8688d0f9a5877f3a', start_time=1749943791053, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'best_epoch': 36.0,
#  'train_accuracy': 66.0919540229885,
#  'train_loss': 0.8211781030351465,
#  'val_accuracy': 65.0,
#  'val_loss': 1.0466620785494645}, params={'HFlip': '0.0',
#  'RBContrast': '0.0',
#  'VFlip': '0.5',
#  'batch_size': '16',
#  'count_params': '1640201',
#  'dropout': '0.3',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '32',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.01',
#  'model': 'MLPClassifier',
#  'optimizer': 'SGD (\n'
#               'Parameter Group 0\n'
#               '    dampening: 0\n'
#               '    differentiable: False\n'
#               '    foreach: None\n'
#               '    fused: None\n'
#               '    lr: 0.01\n'
#               '    maximize: False\n'
#               '    momentum: 0\n'
#               '    nesterov: False\n'
#               '    weight_decay: 0\n'
#               ')',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:25:39.261918", "model_uuid": '
#                              '"05345f040dc44f67a330ca64b2ec70dd", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:25:51.483617", "model_uuid": '
#                              '"2e78abdd4d5b4c65bb38633ae804a70c", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:25:57.637514", "model_uuid": '
#                              '"7026b72fe7544c738c0d5817908a7e5d", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:26:03.412344", "model_uuid": '
#                              '"f3b405d1922a448da9e78fb87dd2c493", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:26:17.806506", "model_uuid": '
#                              '"034c8e61083943f3837decb5dbab079c", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:26:35.262960", "model_uuid": '
#                              '"d705fd2df77d4d6e82378ba22aa7189c", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:26:41.664407", "model_uuid": '
#                              '"1540f3330e1941e097cad399f3b2fb44", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:26:53.593195", "model_uuid": '
#                              '"151702ab49fb473794022d06acb598d8", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:27:00.340608", "model_uuid": '
#                              '"cfc9366905d5432fb770f97beef008e9", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:27:18.158227", "model_uuid": '
#                              '"bdd2deca264d4c34968d655bf26942f4", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:27:24.917028", "model_uuid": '
#                              '"5c6f41a22b6f423b8c8f07b4298b5d75", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:27:42.943496", "model_uuid": '
#                              '"f16cb88aa44f41a3bbd61647376bab51", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:27:49.551685", "model_uuid": '
#                              '"1bfaa58bcf0a42b1a096958c0dcc74fa", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"987d607d03d54f668c2bfb03ac14db74", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:28:07.080721", "model_uuid": '
#                              '"3375cdd8860e42f79802b0fb84e2038f", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'valuable-zebra-717',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/987d607d03d54f668c2bfb03ac14db74/artifacts', end_time=1749929306964, experiment_id='494564464208363776', lifecycle_stage='active', run_id='987d607d03d54f668c2bfb03ac14db74', run_name='valuable-zebra-717', run_uuid='987d607d03d54f668c2bfb03ac14db74', start_time=1749929136500, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'best_epoch': 15.0,
#  'train_accuracy': 74.56896551724138,
#  'train_loss': 0.6787165081636473,
#  'val_accuracy': 63.888888888888886,
#  'val_loss': 1.0315925367176533}, params={'HFlip': '0.0',
#  'RBContrast': '0.0',
#  'VFlip': '0.0',
#  'batch_size': '16',
#  'count_params': '25233161',
#  'dropout': '0.0',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '128',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.01',
#  'model': 'MLPClassifier',
#  'optimizer': 'SGD',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:36:20.946439", "model_uuid": '
#                              '"41502686e3394361ad53193c68458854", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:36:28.953710", "model_uuid": '
#                              '"6a7b138b43014677bfdd6fb38dab5284", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:36:44.046862", "model_uuid": '
#                              '"80f39baeaa2041158112703980957bed", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:36:59.543379", "model_uuid": '
#                              '"960fd45f87264044b1f4bda749ac25df", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:52:36.946901", "model_uuid": '
#                              '"a478c6adfb8a44428145050ba60fcead", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:52:51.823992", "model_uuid": '
#                              '"3caba01ec2e14cf1885ffebd447b34f4", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"8c8bcb08bc0e4bc799ddbc4ad31d904a", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '01:53:06.232165", "model_uuid": '
#                              '"b855fc9afb35414b90e131104ee06c35", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'whimsical-croc-748',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/8c8bcb08bc0e4bc799ddbc4ad31d904a/artifacts', end_time=1749953110463, experiment_id='494564464208363776', lifecycle_stage='active', run_id='8c8bcb08bc0e4bc799ddbc4ad31d904a', run_name='whimsical-croc-748', run_uuid='8c8bcb08bc0e4bc799ddbc4ad31d904a', start_time=1749951377272, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'best_epoch': 13.0,
#  'train_accuracy': 71.12068965517241,
#  'train_loss': 0.7221580689603632,
#  'val_accuracy': 63.333333333333336,
#  'val_loss': 1.1302593151728313}, params={'HFlip': '0.0',
#  'RBContrast': '0.5',
#  'VFlip': '0.0',
#  'batch_size': '64',
#  'count_params': '1640201',
#  'dropout': '0.1',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '32',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.001',
#  'model': 'MLPClassifier',
#  'optimizer': 'Adam',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "f5a8e6731e9242ee945399f24cb482e9", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:57:18.379475", "model_uuid": '
#                              '"ed5aa70eff634262960204e6f61f0c53", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"f5a8e6731e9242ee945399f24cb482e9", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:57:32.072956", "model_uuid": '
#                              '"3d47851283694c42a24435247f2ba2b4", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
# ...
#                              '"aadcce4035d94c65bc66e62f7446bcfc", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:31:08.976215", "model_uuid": '
#                              '"423990dd30b34dae930a3bd9466c8bd1", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"aadcce4035d94c65bc66e62f7446bcfc", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:31:18.007436", "model_uuid": '
#                              '"177739b2cda0458f81b6b54518c22f69", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"aadcce4035d94c65bc66e62f7446bcfc", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:31:24.159281", "model_uuid": '
#                              '"a94d2b05883a4c28b64d69a9b8d86583", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"aadcce4035d94c65bc66e62f7446bcfc", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-14 '
#                              '19:31:32.900152", "model_uuid": '
#                              '"f616e27544114badb00fb09226b46b61", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'polite-mule-12',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/aadcce4035d94c65bc66e62f7446bcfc/artifacts', end_time=1749929512853, experiment_id='494564464208363776', lifecycle_stage='active', run_id='aadcce4035d94c65bc66e62f7446bcfc', run_name='polite-mule-12', run_uuid='aadcce4035d94c65bc66e62f7446bcfc', start_time=1749929453185, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'best_epoch': 23.0,
#  'train_accuracy': 61.0632183908046,
#  'train_loss': 1.0221777160962422,
#  'val_accuracy': 61.111111111111114,
#  'val_loss': 1.2026066184043884}, params={'HFlip': '0.0',
#  'RBContrast': '0.5',
#  'VFlip': '0.0',
#  'batch_size': '128',
#  'count_params': '25233161',
#  'dropout': '0.3',
#  'epochs': '200',
#  'es_patience': '5',
#  'input_size': '128',
#  'loss_fn': 'CrossEntropyLoss',
#  'lr': '0.0001',
#  'model': 'MLPClassifier',
#  'optimizer': 'Adam',
#  'train_dir': 'skin-dataset-clasification/data/Split_smol/train/',
#  'val_dir': 'skin-dataset-clasification/data/Split_smol/val/'}, tags={'mlflow.log-model.history': '[{"run_id": "833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:39:27.869271", "model_uuid": '
#                              '"f2286c67477f491b9c720174a2fb3258", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:39:34.595242", "model_uuid": '
#                              '"a34a3f1189b34c6cbf28b5b37323bde3", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:55:09.916418", "model_uuid": '
#                              '"6723a3359b724ea18857879c88eeaa1b", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:55:16.647776", "model_uuid": '
#                              '"95ec5f21ad8e4090a8f5c08f65b7b08c", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:55:26.517162", "model_uuid": '
#                              '"c689784352584076b2eb92372f9e3c21", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '10:55:42.567669", "model_uuid": '
#                              '"2f66ea888e3646d3a83d4f5c5076972a", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:11:18.014285", "model_uuid": '
#                              '"cffd0ea493fc4e72bd387dafb608969b", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:11:27.945870", "model_uuid": '
#                              '"3611a2eec28a4fcf924146797331cdbc", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:11:34.740344", "model_uuid": '
#                              '"a960d829bcf04daf82912cb6f6b731ce", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:11:56.964678", "model_uuid": '
#                              '"566662efdc3d44ac98c1c8e3db6134d0", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:12:03.689276", "model_uuid": '
#                              '"f08a6d7d373c450bb2c92acbd811393d", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}, {"run_id": '
#                              '"833d6fab64934dd4aaa274104477896d", '
#                              '"artifact_path": "pytorch_model", '
#                              '"utc_time_created": "2025-06-15 '
#                              '11:27:36.245794", "model_uuid": '
#                              '"30a86cdb081347a68f5b529e777f443f", "flavors": '
#                              '{"pytorch": {"model_data": "data", '
#                              '"pytorch_version": "2.7.0", "code": null}, '
#                              '"python_function": {"pickle_module_name": '
#                              '"mlflow.pytorch.pickle_module", "loader_module": '
#                              '"mlflow.pytorch", "python_version": "3.12.3", '
#                              '"data": "data", "env": {"conda": "conda.yaml", '
#                              '"virtualenv": "python_env.yaml"}}}}]',
#  'mlflow.runName': 'gaudy-snake-8',
#  'mlflow.source.name': '/opt/anaconda3/envs/TP_redes/lib/python3.12/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sofia'}>, info=<RunInfo: artifact_uri='file:///Users/sofia/Desktop/ITBA/Redes/TP-Integrador-RN/mlruns/494564464208363776/833d6fab64934dd4aaa274104477896d/artifacts', end_time=1749986878204, experiment_id='494564464208363776', lifecycle_stage='active', run_id='833d6fab64934dd4aaa274104477896d', run_name='gaudy-snake-8', run_uuid='833d6fab64934dd4aaa274104477896d', start_time=1749983964623, status='FINISHED', user_id='sofia'>, inputs=<RunInputs: dataset_inputs=[]>>]
